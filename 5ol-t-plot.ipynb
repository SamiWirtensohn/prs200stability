# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
from scipy.optimize import curve_fit

# %%
data = np.loadtxt('5ol-t.txt', delimiter='\t')

x = data[:,5]
y1 = data[:,2]
y2 = data[:,4]

# %%
def func(x, m, t):
    return m * x + t

popt, pcov = curve_fit(func, x, y1)
mA = popt[0]
tA = popt[1]
popt, mA, tA
# Out:
# (array([0.03880628, 0.05944754]), 0.03880628134897225, 0.059447544536743335)

# %%
popt2, pcov2 = curve_fit(func, x, y2)
mP = popt2[0]
tP = popt2[1]
popt2, mP, tP
# Out:
# (array([0.00435745, 0.00167442]), 0.004357450401475728, 0.0016744184945776386)

# %%
data = np.loadtxt('unabh.txt', delimiter='\t')

xt = data[:,0]
zt = data[:,2]
yt = data[:,4]

# %%
poptU, pcovU = curve_fit(func, xt, zt)
mT = poptU[0]
tT = poptU[1]
poptU, mT, tT
# Out:
# (array([ 0.02486858, -0.11778154]), 0.024868580507879535, -0.11778154050681008)

# %%
plt.plot(x, y1, '.', label= 'Autokollimator')
plt.plot(x, y2, '.', label= 'Pollux')
plt.plot(x, func(x, *popt), 'r-', label='fit_Autokoll')
plt.plot(x, func(x, *popt2), 'g-', label='fit_Pollux')
plt.plot(x, func(x, mA-mT, tA), 'k', label='fit_Autokoll_korrigiert')
plt.title('5 Nm Open Loop')
plt.xlabel('Zeit[min]')
plt.ylabel('Bogensekunden')
plt.legend()
plt.savefig('5ol-t.png', dpi = 300)
plt.show()
