# %%
import matplotlib.pyplot as plt
import csv
import numpy as np
from scipy.optimize import curve_fit

# %%
data = np.loadtxt('0cl.txt', delimiter='\t')

x = data[:,0]
y1 = data[:,2]
y2 = data[:,4]

# %%
def func(x, m, t):
    return m * x + t

popt, pcov = curve_fit(func, x, y1)
popt

#plt.plot(x, func(x, *popt), 'r-', label='fit')
# Out:
# array([0.00582161, 0.04413412])

# %%
def func(x, m, t):
    return m * x + t

popt2, pcov2 = curve_fit(func, x, y2)
popt2
# Out:
# array([2.59459419e-05, 5.20000074e-04])

# %%
plt.plot(x, y1, 'o', label= 'Autokollimator')
plt.plot(x, y2, label= 'Pollux')
plt.plot(x, func1(x, *popt), 'r-', label='fit_Autokoll')
#plt.plot(x, func2(x, *popt2), 'g-', label='fit2')
plt.title('0 Nm Closed Loop')
plt.xlabel('Messung')
plt.ylabel('Bogensekunden')
plt.legend()
#plt.savefig('0cl.png', dpi = 300)
plt.show()
